# %% [markdown]
# # Content Model Smoke Demo
#
# This notebook uses the repository-native `models.TFIDFRecommender` / `models.ContentRecommender` classes with MovieLens-style `movieId` and `userId` columns. Outputs are intentionally cleared before commit.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from data import MovieLensDataLoader
from models import TFIDFRecommender

# %%
bundle = MovieLensDataLoader(ROOT / 'data' / 'sample').load()
model = TFIDFRecommender().fit(bundle.movies, bundle.tags)

# %%
model.recommend_similar_movies(movie_id=1, top_k=5)

# %%
model.recommend_for_user(user_id=104, user_history=bundle.ratings, top_k=5)
